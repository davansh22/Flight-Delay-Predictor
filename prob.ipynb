# %%
import pandas as pd
df = pd.read_csv('flights.csv',sep=",")
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_2076\1844214719.py:2: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('flights.csv',sep=",")

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
import pandas as pd

nan_values = df['DEPARTURE_DELAY'].isnull().values.any()

if nan_values:
    print("There are NaN values in the DataFrame")
else:
    print("No NaN values found")
# Out:
# No NaN values found

# %%
mean_value = data2['DEPARTURE_DELAY'].mean()
data2['DEPARTURE_DELAY'].fillna(mean_value, inplace=True)

# %%
mean_value = data['ARRIVAL_DELAY'].mean()
data['ARRIVAL_DELAY'].fillna(mean_value, inplace=True)

# %% [markdown]
# ### import pandas as pd
# import matplotlib.pyplot as plt
#
#
# data = pd.read_csv('flights.csv')
#
#
# x = data['DAY_OF_WEEK']
# y = data['ARRIVAL_DELAY']
#
# # Create a scatter plot
# plt.scatter(x, y, alpha=0.5)
#
# # Add labels and title
# plt.xlabel('Day of week')
# plt.ylabel('Arrival Delay (minutes)')
# plt.title('Scatter Plot of day of week vs. Arrival Delay')
#
# # Show the plot
# plt.grid(True)
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv('flights.csv')


plt.figure(figsize=(10, 6))  
sns.boxplot(x='DAY_OF_WEEK', y='ARRIVAL_DELAY', data=data)
plt.xlabel('Day of Week')
plt.ylabel('Arrival Delay (minutes)')
plt.title('Arrival Delay vs. Day of Week')

# Show the plot
plt.grid(True)
plt.show()


plt.figure(figsize=(10, 6))  
sns.boxplot(x='DAY_OF_WEEK', y='DEPARTURE_DELAY', data=data)
plt.xlabel('Day of Week')
plt.ylabel('Departure Delay (minutes)')
plt.title('Departure Delay vs. Day of Week')


plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_24568\1813542905.py:7: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv('flights.csv')


mean_arrival_delay = data.groupby('DAY_OF_WEEK')['ARRIVAL_DELAY'].mean()
mean_departure_delay = data.groupby('DAY_OF_WEEK')['DEPARTURE_DELAY'].mean()


plt.figure(figsize=(10, 6))  
sns.barplot(x=mean_arrival_delay.index, y=mean_arrival_delay.values)
plt.xlabel('Day of Week')
plt.ylabel('Mean Arrival Delay (minutes)')
plt.title('Mean Arrival Delay vs. Day of Week')

plt.figure(figsize=(10, 6)) 
sns.barplot(x=mean_departure_delay.index, y=mean_departure_delay.values)
plt.xlabel('Day of Week')
plt.ylabel('Mean Departure Delay (minutes)')
plt.title('Mean Departure Delay vs. Day of Week')


plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_24568\2390141666.py:6: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')

# %%
x
# Out:
# 0          4
# 1          4
# 2          4
# 3          4
# 4          4
#           ..
# 5819074    4
# 5819075    4
# 5819076    4
# 5819077    4
# 5819078    4
# Name: DAY_OF_WEEK, Length: 5819079, dtype: int64

# %%
y
# Out:
# 0         -22.0
# 1          -9.0
# 2           5.0
# 3          -9.0
# 4         -21.0
#            ...
# 5819074   -26.0
# 5819075   -16.0
# 5819076    -8.0
# 5819077   -10.0
# 5819078     2.0
# Name: ARRIVAL_DELAY, Length: 5819079, dtype: float64

# %%
x.mean()
# Out:
# 3.9269411877721545

# %%
y.mean()
# Out:
# 4.407057357987598

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv('flights.csv')


plt.figure(figsize=(10, 6))  
sns.boxplot(x='AIRLINE', y='ARRIVAL_DELAY', data=data)
plt.xlabel('AIRLINE')
plt.ylabel('Arrival Delay (minutes)')
plt.title('Arrival Delay vs. AIRLINE')


plt.grid(True)
plt.show()


plt.figure(figsize=(10, 6)) 
sns.boxplot(x='AIRLINE', y='DEPARTURE_DELAY', data=data)
plt.xlabel('AIRLINE')
plt.ylabel('Departure Delay (minutes)')
plt.title('Departure Delay vs. AIRLINE')


plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_10212\617372023.py:7: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv('flights.csv')


mean_arrival_delay = data.groupby('AIRLINE')['ARRIVAL_DELAY'].mean()
mean_departure_delay = data.groupby('AIRLINE')['DEPARTURE_DELAY'].mean()


plt.figure(figsize=(10, 6))  
sns.barplot(x=mean_arrival_delay.index, y=mean_arrival_delay.values)
plt.xlabel('AIRLINE')
plt.ylabel('Mean Arrival Delay (minutes)')
plt.title('Mean Arrival Delay vs. AIRLINE')

plt.figure(figsize=(10, 6))  
sns.barplot(x=mean_departure_delay.index, y=mean_departure_delay.values)
plt.xlabel('AIRLINE')
plt.ylabel('Mean Departure Delay (minutes)')
plt.title('Mean Departure Delay vs. AIRLINE')


plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_10212\1763349665.py:6: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv('flights.csv')
N=20

top_airports = data['ORIGIN_AIRPORT'].value_counts().head(N)


plt.figure(figsize=(12, 6))  
sns.barplot(x=top_airports.index, y=top_airports.values)
plt.xlabel('ORIGIN_AIRPORT')
plt.ylabel('Flight Frequency')
plt.title(f'Top {N} Origin Airports by Flight Frequency')


plt.xticks(rotation=45)

# Show the plot
plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_10212\3291359261.py:6: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('flights.csv')
N=15

top_airports = data['ORIGIN_AIRPORT'].value_counts().head(N)


mean_arrival_delays = []
mean_departure_delays = []

for airport in top_airports.index:
    subset = data[data['ORIGIN_AIRPORT'] == airport]
    mean_arrival_delays.append(subset['ARRIVAL_DELAY'].mean())
    mean_departure_delays.append(subset['DEPARTURE_DELAY'].mean())


plt.figure(figsize=(12, 6))  
plt.bar(top_airports.index, mean_arrival_delays, label='Mean Arrival Delay')
plt.bar(top_airports.index, mean_departure_delays, label='Mean Departure Delay', alpha=0.7)
plt.xlabel('Origin Airport')
plt.ylabel('Mean Delay (minutes)')
plt.title(f'Mean Arrival and Departure Delays for Top {N} Origin Airports')
plt.legend()


plt.xticks(rotation=45)

# Show the plot
plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_21224\1976753264.py:6: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')

# %%
y_departure_delay = data['DEPARTURE_DELAY']
y_arrival_delay = data['ARRIVAL_DELAY']
data['DAY_OF_WEEK'] = data['DAY_OF_WEEK'].astype(str)
data['ORIGIN_AIRPORT'] = data['ORIGIN_AIRPORT'].astype(str)
data['AIRLINE'] = data['AIRLINE'].astype(str)
selected_columns = ['ORIGIN_AIRPORT', 'AIRLINE','DAY_OF_WEEK'] 
X_train = data[selected_columns]

# %%
import numpy as np
from scipy.sparse import vstack


sample_size = 50000 


selected_indices = np.random.choice(X_train.shape[0], sample_size, replace=False)


X_train_subsample = X_train[selected_indices]
y_departure_delay_subsample = y_departure_delay[selected_indices]
y_arrival_delay_subsample = y_arrival_delay[selected_indices]

# %%
data['DAY_OF_WEEK'].shape
# Out:
# (5819079,)

# %%
X_train.shape[0]
# Out:
# 40000

# %%
from sklearn.model_selection import train_test_split


X_train_dep, X_test_dep, y_train_dep, y_test_dep = train_test_split(X_train_subsample, y_departure_delay_subsample, test_size=0.2, random_state=42)


X_train_arr, X_test_arr, y_train_arr, y_test_arr = train_test_split(X_train_subsample, y_arrival_delay_subsample, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


X_train_dense = X_train_subsample.toarray()


model_departure = Sequential()
model_departure.add(Dense(64, activation='relu', input_shape=(X_train_subsample.shape[1],)))
model_departure.add(Dense(32, activation='relu'))
model_departure.add(Dense(1))  

model_departure.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])


model_departure.fit(X_train_dense, y_departure_delay_subsample, epochs=10, batch_size=32)


departure_loss = model_departure.evaluate(X_test_dep, y_test_dep)
print(f"Mean Squared Error on test data for departure delay: {departure_loss}")
# Out:
# Epoch 1/10
# 1250/1250 [==============================] - 2s 1ms/step - loss: 1319.1447 - mse: 1319.1447
# Epoch 2/10
# 1250/1250 [==============================] - 2s 1ms/step - loss: 1310.8104 - mse: 1310.8104
# Epoch 3/10
# 1250/1250 [==============================] - 1s 1ms/step - loss: 1307.6624 - mse: 1307.6624
# Epoch 4/10
# 1250/1250 [==============================] - 1s 1ms/step - loss: 1304.6575 - mse: 1304.6575
# Epoch 5/10
# 1250/1250 [==============================] - 1s 1ms/step - loss: 1300.3517 - mse: 1300.3517
# Epoch 6/10
# 1250/1250 [==============================] - 1s 1ms/step - loss: 1295.8940 - mse: 1295.8940
# Epoch 7/10
# 1250/1250 [==============================] - 1s 1ms/step - loss: 1290.1117 - mse: 1290.1117
# Epoch 8/10
# 1250/1250 [==============================] - 2s 1ms/step - loss: 1284.6614 - mse: 1284.6614
# Epoch 9/10
# 1250/1250 [==============================] - 2s 1ms/step - loss: 1278.7332 - mse: 1278.7332
# Epoch 10/10
# ...

# %%
import tensorflow as tf
import pandas as pd

data2 = pd.read_csv('flights.csv')


sample_size = 100000
data_subset = data2.head(sample_size)




X_train_day_of_week = data_subset['DAY_OF_WEEK'].values.reshape(-1, 1)  # Reshape for TensorFlow
y_departure_delay = data_subset['DEPARTURE_DELAY'].values


model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)
])


model.compile(optimizer='adam', loss='mean_squared_error')


model.fit(X_train_day_of_week, y_departure_delay, epochs=10, batch_size=32) 


input_data = pd.DataFrame({'DAY_OF_WEEK': [1, 2, 3]})  
input_data_numpy = input_data.values.reshape(-1, 1)  

departure_delay_predictions = model.predict(input_data_numpy)
print("Predicted Departure Delays:", departure_delay_predictions)
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_5176\387500336.py:4: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2 = pd.read_csv('flights.csv')
# Epoch 1/10
# 3125/3125 [==============================] - 3s 932us/step - loss: nan
# Epoch 2/10
# 3125/3125 [==============================] - 3s 840us/step - loss: nan
# Epoch 3/10
# 3125/3125 [==============================] - 3s 831us/step - loss: nan
# Epoch 4/10
# 3125/3125 [==============================] - 3s 881us/step - loss: nan
# Epoch 5/10
# 3125/3125 [==============================] - 3s 1ms/step - loss: nan
# Epoch 6/10
# 3125/3125 [==============================] - 3s 888us/step - loss: nan
# Epoch 7/10
# 3125/3125 [==============================] - 3s 900us/step - loss: nan
# Epoch 8/10
# 3125/3125 [==============================] - 3s 867us/step - loss: nan
# Epoch 9/10
# 3125/3125 [==============================] - 3s 894us/step - loss: nan
# Epoch 10/10
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
import pandas as pd

data = pd.read_csv('flights.csv')


sample_size = 100000
data_subset = data.head(sample_size)


X_train_day_of_week = data_subset[['DAY_OF_WEEK']]
y_departure_delay = data_subset['ARRIVAL_DELAY']


y_departure_delay = y_departure_delay.fillna(0) 


tree_model_day_of_week = DecisionTreeRegressor()


tree_model_day_of_week.fit(X_train_day_of_week, y_departure_delay)


input_data = pd.DataFrame({'DAY_OF_WEEK': [1, 7, 6]})  # Example input for prediction


departure_delay_predictions = tree_model_day_of_week.predict(input_data)
print("Predicted Departure Delays:", departure_delay_predictions)
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_5176\1813972528.py:4: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')
# Predicted Departure Delays: [18.27248006 31.06574119 24.82836595]

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('flights.csv')


mean_departure_delay = data.groupby('DISTANCE')['DEPARTURE_DELAY'].mean()

plt.figure(figsize=(10, 6))
mean_departure_delay.plot(color='blue')
plt.title('Mean Departure Delay by Distance')
plt.xlabel('Distance')
plt.ylabel('Mean Departure Delay')
plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_5176\2260456861.py:5: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('flights.csv')

mean_departure_delay = data.groupby('AIR_TIME')['ARRIVAL_DELAY'].mean()


plt.figure(figsize=(10, 6))
mean_departure_delay.plot(color='blue')
plt.title('Mean Departure Delay by air time')
plt.xlabel('Distance')
plt.ylabel('Mean Departure Delay')
plt.grid(True)
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_5176\1838736612.py:5: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')

# %%
from sklearn.tree import DecisionTreeRegressor
import pandas as pd

data = pd.read_csv('flights.csv')


sample_size = 100000
data_subset = data.head(sample_size)

X_train_features = data_subset[['DAY_OF_WEEK', 'DISTANCE','AIR_TIME']]
y_departure_delay = data_subset['DEPARTURE_DELAY']

y_departure_delay = y_departure_delay.fillna(0)  


tree_model = DecisionTreeRegressor()


tree_model.fit(X_train_features, y_departure_delay)

input_data = pd.DataFrame({'DAY_OF_WEEK': [1, 7, 6], 'DISTANCE': [500, 1000, 1500], 'AIR_TIME': [200, 400, 600]})  # Example input for prediction

departure_delay_predictions = tree_model.predict(input_data)
print("Predicted Arrival Delays:", departure_delay_predictions)
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_5176\4001199394.py:4: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('flights.csv')
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[27], line 4
#       1 from sklearn.tree import DecisionTreeRegressor
#       2 import pandas as pd
# ----> 4 data = pd.read_csv('flights.csv')
#       6 # Select a subset of rows for training (e.g., first 100,000 rows)
#       7 sample_size = 100000
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
from sklearn.metrics import mean_absolute_error

true_values = data_subset['DEPARTURE_DELAY'].fillna(0)  

mae = mean_absolute_error(true_values, tree_model.predict(X_train_features))
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Absolute Error (MAE): 25.82369478909754

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('flights.csv')

sample_size = 100000
data_subset = df.head(sample_size)


columns_to_encode = ['AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT']

label_encoder = LabelEncoder()
encoding_mapping = {}

for column in columns_to_encode:
    data_subset[column] = label_encoder.fit_transform(data_subset[column])
    encoding_mapping[column] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

print(data_subset.head())
print("Encoding mapping for AIRLINE:", encoding_mapping['AIRLINE'])
print("Encoding mapping for ORIGIN_AIRPORT:", encoding_mapping['ORIGIN_AIRPORT'])
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_2076\2711046322.py:4: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('flights.csv')
#    YEAR  MONTH  DAY  DAY_OF_WEEK  AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4        1             98      N407AS
# 1  2015      1    1            4        0           2336      N3KUAA
# 2  2015      1    1            4       11            840      N171US
# 3  2015      1    1            4        0            258      N3HYAA
# 4  2015      1    1            4        1            135      N527AS
#
#    ORIGIN_AIRPORT  DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 0              15                  268                    5  ...
# 1             168                  226                   10  ...
# 2             269                   62                   20  ...
# 3             168                  195                   20  ...
# ...

# %%
'''import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

from sklearn.tree import DecisionTreeRegressor
import pandas as pd

    
X_train_features = data_subset[['AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT','DISTANCE','AIR_TIME']]
y_departure_delay = data_subset['DEPARTURE_DELAY']

    
y_departure_delay = y_departure_delay.fillna(0)  
from sklearn.model_selection import train_test_split

# Assuming 'data_subset' is your dataset
X_train, X_test, y_train, y_test = train_test_split(
    data_subset[['AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT','DISTANCE','AIR_TIME']],
    y_departure_delay,
    test_size=0.2,  # You can adjust the test_size as needed
    random_state=42  # Set a random seed for reproducibility
)
   
tree_model = DecisionTreeRegressor()

    
tree_model.fit(X_train, y_train)

   
input_data = pd.DataFrame({'AIRLINE': [0], 'ORIGIN_AIRPORT': [3], 'DESTINATION_AIRPORT': [5], 'DISTANCE': [1500], 'AIR_TIME': [200]})  

departure_delay_predictions = tree_model.predict(input_data)
print("Predicted DEPARTURE Delays:", departure_delay_predictions)
'''
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

from sklearn.tree import DecisionTreeRegressor
import pandas as pd

    
X_train_features = data_subset[['AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT']]
y_departure_delay = data_subset['DEPARTURE_DELAY']

    
y_departure_delay = y_departure_delay.fillna(0)  
from sklearn.model_selection import train_test_split

# Assuming 'data_subset' is your dataset
X_train, X_test, y_train, y_test = train_test_split(
    data_subset[['AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT']],
    y_departure_delay,
    test_size=0.2,  # You can adjust the test_size as needed
    random_state=34  # Set a random seed for reproducibility
)
   
tree_model = DecisionTreeRegressor()

    
tree_model.fit(X_train, y_train)

   
input_data = pd.DataFrame({'AIRLINE': [0], 'ORIGIN_AIRPORT': [3], 'DESTINATION_AIRPORT': [5]})  

departure_delay_predictions = tree_model.predict(input_data)
print("Predicted DEPARTURE Delays:", departure_delay_predictions)
# Out:
# Predicted DEPARTURE Delays: [26.75]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Assuming 'tree_model' is your trained decision tree model

# Make predictions on the test set
y_pred = tree_model.predict(X_test)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Absolute Error (MAE): 26.770669120571633
